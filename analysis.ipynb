# %%
import pandas as pd

# %%
df =pd.read_csv('compiled_circuits/circuitData.csv')
df.head()
# Out:
#   Circuit QASM File Name Before Optimization  \
# 0                    bigadder_n18_transpiled
# 1                    bigadder_n18_transpiled
# 2                    bigadder_n18_transpiled
# 3                         dnn_n16_transpiled
# 4                         dnn_n16_transpiled
#
#            Circuit QASM File Name After Optimization  Circuit Qubit Count  \
# 0  bigadder_n18_transpiled_1e-08_QuckPartitioner3...                   18
# 1  bigadder_n18_transpiled_1e-08_QuckPartitioner3...                   18
# 2         bigadder_n18_transpiled_OptimizationLevel3                   18
# 3  dnn_n16_transpiled_1e-08_QuckPartitioner3_QSearch                   16
# 4     dnn_n16_transpiled_1e-08_QuckPartitioner3_LEAP                   16
#
#    Compilation Time (seconds)  Two-Qubit Gate Count Before Optimization  \
# 0                   22.496278                                       130
# 1                    5.339639                                       130
# ...
